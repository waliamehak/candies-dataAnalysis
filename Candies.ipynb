# %% [markdown]
# <a href="https://colab.research.google.com/github/waliamehak/candies-dataAnalysis/blob/main/Candies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mehak Jeet Singh Walia

# %% [markdown]
# #**Description**
# Since 2006 David Ng and Ben Cohen at the University of British Columbia have been ranking Halloween candies based on an informal subjective measurement — the “net feelies axiom” which varies from JOY to DISPAIR. As of 2014, the duo has been collecting large sets of data in the form of an online survey:
# https://www.scq.ubc.ca/wp-content/uploads/2017/10/candyhierarchysurvey2017.pdf
#
#
# The data-sets and their descriptions can be found here:
# https://www.scq.ubc.ca/so-much-candy-data-seriously/
# https://www.scq.ubc.ca/2016-candy-hierarchy-supplemental-raw-data-and-new-analyses/
# https://www.scq.ubc.ca/2015-candy-hierarchy-supplemental-raw-data-and-new-analyses/
# https://www.scq.ubc.ca/candy-hierarchy-2014-supplementary-raw-data/
# In this notebook, I set out analyse the data and draw some inferences from it by answering some questions.

# %% [markdown]
# #**Prepare, Clean and Normailze the Data**
# After downloading the datasets into my local drive, I perused them all very carefully. The very first thing that I noticed was that the 2014 dataset is not going to be of much use to us as it is not person oriented but rather product oriented data. What I mean to say here is that, we dont get to know about the personal preference of an individual on the different candies. Neither we get to know their origin, age or sex. All these factors are crucial if I am to know the likability of candies based on region, sex, etc. So, I ignored this dataset. \
# Now, I cleaned the data by removing the columns from each dataset one by one that would not aid us by answering the questions asked. These columns essentially were the ones that stored a response to questions not related to the individual's preferences on different candies. \
# I made sure that each data set just contains the personal information and  their preference on candies and nothing else. I dropped all the columns in preprocessing until I had the results that I wanted. \
# After cleaning the data, I noticed that the datasets have different number of columns. This essentially meant that we dont have the data on candies for all the three years, i.e., some candies were officially added to the survey while others were removed in each survey.\
# For me the concern was to make sure that when I join the datasets, the information should fall under the right columns. That is, if there exists data for a candy in first data set, if should concatinate under the data for same candy in the other datasets and not make its own new seperate column. \
# For this to happen the column names should be the same for the same candy. I noticed that for 2015, and 2016 the columns names were same and not any significant changes were to be made. However for 2017, the column names were not same. So, I also changed the names of the columns for which there existed data in 2015 and 2016. I did that by using string handling function ( split) on it and change the column names in 2017.

# %%
I started by importing the libraries listed below.

# %%
import pandas as pd
from google.colab import files
import io
import numpy as np

# %% [markdown]
# The next order of business was to load the data sets into colab. I did it using upload function. Upon running the command it asks us to choose files from our local disk and simply uploads into the colab. [1]

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-147f0a18-07bc-45e2-83f6-83c0df58997f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-147f0a18-07bc-45e2-83f6-83c0df58997f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2014dataFINAL.csv to 2014dataFINAL.csv
# Saving 2015dataFINAL.csv to 2015dataFINAL.csv
# Saving 2016dataFINAL.csv to 2016dataFINAL.csv
# Saving 2017dataFINAL.csv to 2017dataFINAL.csv

# %% [markdown]
#  I decided to reclean the data in 2016 datset by removing some additional columns and then finally reuploaded the file into colab.

# %%
d=files.upload()
# Out:
#      <input type="file" id="files-72bcace2-966c-4352-a1cc-ec6d581ca26b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72bcace2-966c-4352-a1cc-ec6d581ca26b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2016dataFINAL1.csv to 2016dataFINAL1.csv

# %%
df2014=pd.read_csv(io.StringIO(uploaded['2014data.csv'].decode('utf-8'))) # Load the CSV files into dataframe
df2015=pd.read_csv(io.StringIO(uploaded['2015dataFINAL.csv'].decode('utf-8')))
df2017=pd.read_csv(io.StringIO(uploaded['2017dataFINAL.csv'].decode('utf-8')))

# %%
newone=pd.read_csv(io.StringIO(d['2016dataFINAL1.csv'].decode('utf-8'))) #newone dataframe contains the 2016

# %%
newone.describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count          1250             1226                          1238
# unique            4               98                           101
# top            Male               35                           USA
# freq            795               50                           433
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                           1180            1181
# unique                                           319               3
# top                                       California             MEH
# freq                                              69             552
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                1233
# unique                                                  3
# top                                               DESPAIR
# ...

# %%
df2015=pd.read_csv("2015dataFINAL.csv")
df2016=pd.read_csv("2016dataFINAL.csv")
df2017=pd.read_csv("2017dataFINAL.csv")

# %%
df2017.describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count          2419             2376                          2396
# unique            4              106                           128
# top            Male               40                           USA
# freq           1467               92                           699
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                           2360            1713
# unique                                           511               3
# top                                       California             JOY
# freq                                             132             873
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                1726
# unique                                                  3
# top                                               DESPAIR
# ...

# %% [markdown]
# I can here see that my 2017 data set column names are same as that of 2016 and ready to be merged.

# %% [markdown]
# I simply used concat command to merge the three datasets. As I said earlier, I did not use 2014 data set.

# %%
result = pd.concat([df2017, newone, df2015],ignore_index=True, sort=False)

# %%
result
# Out:
#       Your gender: How old are you? Which country do you live in?  \
# 0              NaN              NaN                           NaN
# 1             Male               44                          USA
# 2             Male               49                           USA
# 3             Male               40                            us
# 4             Male               23                           usa
# ...            ...              ...                           ...
# 10239          NaN               50                           NaN
# 10240          NaN               43                           NaN
# 10241          NaN               35                           NaN
# 10242          NaN               38                           NaN
# 10243          NaN               44                           NaN
#
#       Which state, province, county do you live in? [100 Grand Bar]  \
# 0                                               NaN             NaN
# ...

# %% [markdown]
# I see that there are 128 columns which is the right amount of the columns there should have been for my dataset. This means I have successfully combined the data. For columns which did not exist in the other datasets, they simply stored 'Nan' values for the rows which came from other two datasets.\
# I understood that there wont be any benefit of removing 'Nan' values as they would not matter in the questions asked anyways, so I let them be.

# %%
result.describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count          3669             9033                          3634
# unique            4              203                           182
# top            Male               35                           USA
# freq           2262              368                          1132
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                           3540            7868
# unique                                           648               3
# top                                       California             JOY
# freq                                             201            4852
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                8291
# unique                                                  3
# top                                               DESPAIR
# ...

# %% [markdown]
# TO find unique values inside the columns. [2]

# %%
result['Your gender:'].unique() # curious why I saw 4 unique genders, I made it my mission to find those four values and here they are!
# Out:
# array([nan, 'Male', 'Female', "I'd rather not say", 'Other'], dtype=object)

# %%
result['Which country do you live in?'].unique()
# Out:
# array([nan, 'USA ', 'USA', 'us', 'usa', 'canada', 'Canada', 'Us', 'US',
#        'Murica', 'United States', 'uk', 'United Kingdom', 'united states',
#        'Usa', 'United States ', 'United staes',
#        'United States of America', 'UAE', 'England', 'UK', 'canada ',
#        'Mexico', 'United states', 'u.s.a.', 'USAUSAUSA', 'america', '35',
#        'france', 'United States of America ', 'U.S.A.', 'finland',
#        'unhinged states', 'Canada ', 'united states of america',
#        'US of A', 'Unites States', 'The United States', 'North Carolina ',
#        'Unied States', 'Netherlands', 'germany', 'Europe', 'Earth', 'U S',
#        'u.s.', 'U.K. ', 'Costa Rica', 'The United States of America',
#        'unite states', 'U.S.', '46', 'cascadia', 'Australia',
#        'insanity lately', 'Greece', 'USA? Hard to tell anymore..',
#        "'merica", 'usas', 'Pittsburgh', '45', 'United State', '32',
#        'France', 'australia', 'A', 'Can', 'Canae', 'New York',
# ...

# %% [markdown]
# ## I never knew USA could be spelled in so many ways!
# Interesting, but this make things tough for us to answer!

# %% [markdown]
# #Lets explore the data by asking some random questions

# %% [markdown]
# #Question 1- Women between the ages of 20-30 and the most liked candy by them.

# %% [markdown]
# Numpy library came to rescue here!

# %%
womensInTheRange= np.where( (result["How old are you?"] >= "20")& (result["Your gender:"] == "Female") & (result["How old are you?"] <= "30")) # The result stored the indices to the rows which satisfy the conditions.

# %%
Womensdata=result.loc[womensInTheRange]

# %%
Womensdata.describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count           225              225                           225
# unique            1               11                            26
# top          Female               30                 United States
# freq            225               43                            60
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                            223             167
# unique                                           122               3
# top                                       California             MEH
# freq                                              13              85
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                 171
# unique                                                  3
# top                                               DESPAIR
# ...

# %% [markdown]
# So, describe provides us with alot of insights. I know that freq is the count of the mot common value in that column. So if top says "JOY", then freq says how many people voted "JOY" and 'count-freq' says how many voted 'DESPAIR' or 'MEH'. So, by analysing the dataframe, I see that "Cash, or other forms of legal tender" is the most liked form of gift women like. 161/180 women voted joy. Cominig to an actual candy, I see "Any full-sized candy bar" being the most liked candy among the group.

# %% [markdown]
# ## Question 2-Most despised in Canada
# Coming to the second question, I needed to look only for rows that have Canada as the country column.

# %%
peopleInCanada=np.where( (result["Which country do you live in?"] == "canada") | (result["Which country do you live in?"] == "Canada") | (result["Which country do you live in?"] == "canada ") | (result["Which country do you live in?"] == "Canada ") |
          (result["Which country do you live in?"] == "Can") |
          (result["Which country do you live in?"] == "Canada`") |
          (result["Which country do you live in?"] == "CANADA") )

# %% [markdown]
# I concatenated the indexes with the all possible ways Canada could have been spelled. I could also have defined a dictionary and essentially clean the data but I decided to stick with the original data and perform the opertaions manually as they are equally time consuming. [3]

# %%
canadaStats=result.loc[peopleInCanada]

# %%
canadaStats.describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count           342              342                           344
# unique            4               57                             7
# top            Male               40                        Canada
# freq            186               18                           278
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                            338             217
# unique                                            53               3
# top                                          Ontario             MEH
# freq                                              95             151
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                 270
# unique                                                  3
# top                                               DESPAIR
# ...

# %% [markdown]
# Here, we have our insights for the country Canada and what they like and not like when it comes to candies. \
#
# I see that **"Kale smoothie", "Gum from baseball cards", "Dental paraphenalia", "Candy that is clearly just the stuff given out for free at restaurants" top the charts with 204/259 votes, 203/259 votes, 201/269 votes, 197/273 votes** respectively.

# %% [markdown]
# #Question 3- Most despised and liked in the USA

# %%
peopleOfUSA=np.where( (result["Which country do you live in?"] == "USA ") | (result["Which country do you live in?"] == "USA") | (result["Which country do you live in?"] == "us") | (result["Which country do you live in?"] == "usa") |
          (result["Which country do you live in?"] == "Us") |
          (result["Which country do you live in?"] == "US") |
          (result["Which country do you live in?"] == "United States") |
          (result["Which country do you live in?"] == "united states") |
         (result["Which country do you live in?"] == "Usa") |
         (result["Which country do you live in?"] == "United States") |
         (result["Which country do you live in?"] == "United staes") |(result["Which country do you live in?"] == "United States of America") |
         (result["Which country do you live in?"] == "United states") |
         (result["Which country do you live in?"] == "u.s.a") |
         (result["Which country do you live in?"] == "USAUSAUSA") |
         (result["Which country do you live in?"] == "america") |(result["Which country do you live in?"] == "United States of America ") |
         (result["Which country do you live in?"] == "U.S.A.") |
         (result["Which country do you live in?"] == "unhinged states") |
         (result["Which country do you live in?"] == "united states of america") |
         (result["Which country do you live in?"] == "US of A") |
         (result["Which country do you live in?"] == "Unites States") |
         (result["Which country do you live in?"] == "The United States") |
         (result["Which country do you live in?"] == "North Carolina ") |
         (result["Which country do you live in?"] == "Unied States") |
         (result["Which country do you live in?"] == "U S") |
         (result["Which country do you live in?"] == "u.s.") |
         (result["Which country do you live in?"] == "The United States of America") |
         (result["Which country do you live in?"] == "unite states") |
         (result["Which country do you live in?"] == "USA? Hard to tell anymore..") |
         (result["Which country do you live in?"] == "merica") |
         (result["Which country do you live in?"] == "usas") |
         (result["Which country do you live in?"] == "United State") |
         (result["Which country do you live in?"] == "New York") |
         (result["Which country do you live in?"] == "Trumpistan") |
         (result["Which country do you live in?"] == "United Sates") |
         (result["Which country do you live in?"] == "USa") |
         (result["Which country do you live in?"] == "I pretend to be from Canada, but I am really from the United States.") |
         (result["Which country do you live in?"] == "Usa ") |
         (result["Which country do you live in?"] == "United Stated") |
         (result["Which country do you live in?"] == "Ahem....Amerca") |
         (result["Which country do you live in?"] == "United ststes") |
         (result["Which country do you live in?"] == "America") |
         (result["Which country do you live in?"] == "United Statss") |
         (result["Which country do you live in?"] == "USA! USA! USA!") |
         (result["Which country do you live in?"] == "USAA") |
         (result["Which country do you live in?"] == "united States ") |
         (result["Which country do you live in?"] == "USSA") |
         (result["Which country do you live in?"] == "U.S. ") |
         (result["Which country do you live in?"] == "u s a") |
         (result["Which country do you live in?"] == "United Statea") |
         (result["Which country do you live in?"] == "united ststes") |
         (result["Which country do you live in?"] == "USA USA USA!!!!") |(result["Which country do you live in?"] == "uSA") |
         (result["Which country do you live in?"] == "USA!', 'this one") |
         (result["Which country do you live in?"] == "USA (I think but it's an election year so who can really tell)") |
         (result["Which country do you live in?"] == "America ") |
         (result["Which country do you live in?"] == "Units States") |
         (result["Which country do you live in?"] == "USA USA USA") |
         (result["Which country do you live in?"] == "the best one - usa") |
         (result["Which country do you live in?"] == "united states ") |
         (result["Which country do you live in?"] == "USA!!!!!!") |
         (result["Which country do you live in?"] == " United States") |
         (result["Which country do you live in?"] == "USA! USA!") |
         (result["Which country do you live in?"] == "U.s.") |
         (result["Which country do you live in?"] == "UNited States") |
         (result["Which country do you live in?"] == "United Stetes") |
         (result["Which country do you live in?"] == "USA USA USA USA") |
         (result["Which country do you live in?"] == "United  States of America")         
           )

# %% [markdown]
# I could not help but laugh at the way people have spelled the USA. My favourite ones being; "USA (I think but it's an election year so who can really tell)" and "Trumpistan"

# %%
USAStats=result.loc[peopleOfUSA]
USAStats
# Out:
#      Your gender: How old are you? Which country do you live in?  \
# 1            Male               44                          USA
# 2            Male               49                           USA
# 3            Male               40                            us
# 4            Male               23                           usa
# 6            Male               53                           usa
# ...           ...              ...                           ...
# 3712       Female               56                           USA
# 3713         Male               54                           USA
# 3714       Female               52                           USA
# 3715         Male               33                 united states
# 3718       Female               44                            Us
#
#      Which state, province, county do you live in? [100 Grand Bar]  \
# 1                                               NM             MEH
# ...

# %% [markdown]
# So we have a total of 3007 enteries for people who I could discern as living in the States.

# %%
USAStats['Which state, province, county do you live in?'].unique()
# Out:
# array(['NM', 'Virginia', 'or', 'exton pa', 'Colorado ', 'Wa', 'NY',
#        'Texas', 'NEW YORK', 'CO', 'IN', 'MN', 'Wisconsin, 53705', 'RI',
#        'NC', 'minnesota', 'Michigan', 'Florida', 'New Jersey', 'VA',
#        'Colorado', 'Los Angeles, California', 'CA', 'Chicago, Illinois',
#        'Nj', 'Wisconsin', 'Minnesota ', 'mn', 'TEXAS', 'Illinois',
#        'District of Columbia', 'Washington', 'Massachusetts ', 'OR',
#        'Montana', 'New York', 'massachusetts', 'TX', 'Arizona', 'Dc',
#        'MD', 'Ohio', 'DC', 'Iowa', 'Mn', 'TN', 'Maryland', 'MI',
#        'Wisconsin ', 'alaska', 'Ny', 'Colorado, Jefferson county ',
#        'California', 'Louisiana', 'pa', 'CO, Larimer County', 'Nebraska ',
#        'Oregon', 'UT', 'ny', 'Pennsylvania', 'north carolina', 'Texas ',
#        'Knox county, Tennessee', 'New Mexico', 'Maine',
#        'Virginia, Arlington', 'WA', 'MO', 'Illinois ', 'Mi', 'MA',
#        'Alaska', 'New York, NY', 'Il', 'PA', 'Washington ',
# ...

# %%
USAStats.describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count          2995             2981                          3007
# unique            4              114                            65
# top            Male               34                           USA
# freq           1873              112                          1132
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                           2960            2450
# unique                                           461               3
# top                                       California             JOY
# freq                                             198            1265
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                2447
# unique                                                  3
# top                                               DESPAIR
# ...

# %%
USAStats.groupby(["Which state, province, county do you live in?"]).count() # I used group by command to group by provinces, and I still got an astounding list of 461 provinces.
# Out:
#                                                Your gender:  How old are you?  \
# Which state, province, county do you live in?
# 7940                                                      1                 1
# AK                                                        1                 1
# AL                                                        2                 2
# AR                                                        2                 2
# AZ                                                        9                 9
# ...                                                     ...               ...
# wisconisin                                                1                 1
# wisconsin                                                 5                 5
# wv                                                        1                 1
# wyoming                                                   1                 1
# ...

# %% [markdown]
# Although count is not the perfect method that I could come up with to answer the third question but it does gives me an idea of how the data is distributed.
# Hear me out, it is a lengthy solution to the question asked but it will do provide with the results we seek. \
# Here, I see the count under the candies name. Count represents the frequency of the most common value in that row. So in a row, I will sought out, say first four highest counts, then go into the actual data and filter the results for that province only and see what was repeated more freuently, Liked or  not liked. \
# I took four values of the count just to be on safe side, as it is possible the first two highest counts may represent the same things, that is either liked or not liked.

# %%
Teens= np.where( (result["How old are you?"] <= "20"))

# %%
result.loc[Teens].describe()
# Out:
#        Your gender: How old are you? Which country do you live in?  \
# count           111              374                           110
# unique            4               29                            35
# top          Female               20                           USA
# freq             50               64                            27
#
#        Which state, province, county do you live in? [100 Grand Bar]  \
# count                                            100             296
# unique                                            76               3
# top                                               NJ             JOY
# freq                                               3             135
#
#        [Anonymous brown globs that come in black and orange wrappers]  \
# count                                                 327
# unique                                                  3
# top                                               DESPAIR
# ...

# %% [markdown]
# #INFERENCE

# %% [markdown]
# When looking at the data I could not help but notice that the data is extremely helpful to help with the sales of candies in grocery and candy stores. We can easily predict from the data which of the candies are going to be in demand and the stores can benefit from having extra supplies of those candies. This will lead to better revenues overall and also more importantly happpy customers who would not have to settle for something else upon finding that their favourite candies have gone out of stock in times like Haloween. \
# Above I was curious, which type of candies does the children under 20 prefer. I can see they are almost uniformly attracted to chocolate candies. More children seem to have a sweet tooth and will prefer them over other types, say gummy. \
# Stores can smartly arrange their shelves, making the people favourite candies placed at the end of the aisles and also on the top shelves rather than at the bottom shelves. The data speaks for itself, even this notebook it would be enough for a data scientist to persuade a candy store into buying more of the most liked candies so that they would not go out of stock when other stores have already. When they have a limited money, they should invest them on the right things.\
# One thing that I also noticed was that the data could have had collected much more meticulously which would help store and process the data more elegantly. People should have freedom of expression but not alteast on the questionarries. They should have been prompted to select the countries from a drop down list. Similarly it would have helped to add drop down lists or checkboxes where ever possible to reduce the sample input.

# %% [markdown]
# # References
# 1. Medium. 2020. How To Upload / Read A Local .Csv Or Excel Using Python Pandas Into Google’S Colab?. [online] Available at: <https://medium.com/@mhd.ali.nasser/how-to-upload-read-a-local-csv-or-excel-using-python-pandas-into-googles-colab-9304a11b870e> [Accessed 19 November 2020].
# 2. Python and R Tips. 2020. How To Get Unique Values From A Column In Pandas Data Frame? - Python And R Tips. [online] Available at: <https://cmdlinetips.com/2018/01/how-to-get-unique-values-from-a-column-in-pandas-data-frame/> [Accessed 19 November 2020].
# 3. conditions, N., Amola, A. and Wang, X., 2020. Numpy Where Function Multiple Conditions. [online] Stack Overflow. Available at: <https://stackoverflow.com/questions/16343752/numpy-where-function-multiple-conditions> [Accessed 19 November 2020].
